# %%
import pandas as pd

# %%
data = {"Name": ["spongebob", "Patrick", "Squidward"],
        "Age" : [30,35,50]
}

df = pd.DataFrame(data, index= ["Employee#1","Employee#2","Employee#3" ])


# print(df.loc["Employee#3"])

# print(df.iloc[1])

# Add a new column

df["Job"] = ["Cook", "N/A", "Cashier"]
# print(df)

# Add a new row

new_row = pd.DataFrame([{"Name": "Sandy", "Age" : 28, "Job" : "Engineer" },
                        {"Name": "Eugene", "Age" : 60, "Job" : "Manager" },
                        ],
                       index = ["Employee#4","Employee#5"])
df = pd.concat([df,new_row])
print(df)
# Out:
# Name    Squidward
# Age            50
# Name: Employee#3, dtype: object
#                  Name  Age       Job
# Employee#1  spongebob   30      Cook
# Employee#2    Patrick   35       N/A
# Employee#3  Squidward   50   Cashier
# Employee#4      Sandy   28  Engineer
# Employee#5     Eugene   60   Manager

# %%
#Task

data = {"Name" : ["Ali", "Ahmed" , "Kamran", "Sami", "Zahoor"],
        "Age": [20,24,25,28,35],
        "Job" : ["Engineer", "Coder", "Developer", "Tester", "Deployer"]
}

df = pd.DataFrame(data, index = ["Agent 1","Agent 2","Agent 3","Agent 4","Agent 5"])

#New Column

df["Experience"] = [1,3,5,2,8]

# New Row

new_row = pd.DataFrame([{"Name" : "Ahad", "Age" : 29 , "Job": "Manager", "Experience" : 7},
                        {"Name" : "Salman", "Age" : 23 , "Job": "Head", "Experience" : 5},
                        ],index= ["Agent 6", "Agent 7"]
                        )

df = pd.concat([df,new_row])

# print(df)

print(df.loc["Agent 7"])
# Out:
# Name          Salman
# Age               23
# Job             Head
# Experience         5
# Name: Agent 7, dtype: object
