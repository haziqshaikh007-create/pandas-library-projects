# %%
import pandas as pd

# %%
df = pd.read_csv("data.csiv")
# print(df)

avg_height = df["Height"].mean()
# print(avg_height)

total_legendary = df["Legendary"].sum()
# print(total_legendary)

# print("All the present values for each column are: \n", df.count())

# print("The max value of height for any Pokemon is :", df["Height"].max())

# print("The Minimum Weight of any Pokemon is :", df["Weight"].min())

# %% [markdown]
# Group-By Analogy

# %%
print(df["Type2"].count())
group = df.groupby("Type2")

print(group[["Height","Weight"]].sum())
# Out:
# 67
#           Height  Weight
# Type2
# Fairy        2.8    72.0
# Fighting     1.3    54.0
# Flying      30.9  1163.7
# Grass        1.3    34.9
# Ground      14.3   757.0
# Ice          5.7   472.5
# Poison      20.9   404.8
# Psychic      7.7   357.6
# Rock         2.9   235.0
# Steel        1.3    66.0
# Water        3.2    94.5
