# %%
import pandas as pd

# %%
df = pd.read_csv("data.csiv")

#Selection by column
# print(data["Height"].to_string())
# print(data["Weight"].to_string())
print(data[["Name","Height","Legendary"]].to_string())
# Out:
#            Name  Height  Legendary
# 0     Bulbasaur     0.7          0
# 1       Ivysaur     1.0          0
# 2      Venusaur     2.0          0
# 3    Charmander     0.6          0
# 4    Charmeleon     1.1          0
# 5     Charizard     1.7          0
# 6      Squirtle     0.5          0
# 7     Wartortle     1.0          0
# 8     Blastoise     1.6          0
# 9      Caterpie     0.3          0
# 10      Metapod     0.7          0
# 11   Butterfree     1.1          0
# 12       Weedle     0.3          0
# 13       Kakuna     0.6          0
# 14     Beedrill     1.0          0
# 15       Pidgey     0.3          0
# 16    Pidgeotto     1.1          0
# 17      Pidgeot     1.5          0
# 18      Rattata     0.3          0
# 19     Raticate     0.7          0
# 20      Spearow     0.3          0
# 21       Fearow     1.2          0
# 22        Ekans     2.0          0
# 23        Arbok     3.5          0
# 24      Pikachu     0.4          0
# 25       Raichu     0.8          0
# ...

# %%
df = pd.read_csv("data.csiv",index_col="Name")


#Selection by row

# print(df.iloc[0])
# print(df.loc["Charizard",["Height","Weight"]])
# print(df.loc["Charizard":"Pikachu"]) # Slicing
# print(df.iloc[0:11:2,1:3])

pokemon = input("Enter a pokemon name: ").title()

try:
         print(df.loc[pokemon])

except:
         print(f"{pokemon} does not exist ")
# Out:
# No                 25
# Type1        Electric
# Type2             NaN
# Height            0.4
# Weight            6.0
# Legendary           0
# Name: Pikachu, dtype: object
