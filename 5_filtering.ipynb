# %%
import pandas as pd

# %%
df = pd.read_csv("data.csiv",index_col="Name")
# print(df)

tall_pokemon = df[df["Height"] >= 2]

# print(tall_pokemon.to_string())

heavy_pokemon = df[df["Weight"] >=150]
# print(heavy_pokemon)
# print(heavy_pokemon.loc["Onix"])

legendary_pokemon = df[df["Legendary"] == 1]
# print(legendary_pokemon)

Water_pokemon = df[(df["Type1"] == "Water" ) | 
                   (df["Type2"] == "Ice")]
print(Water_pokemon.iloc[5:11:2,1:4])

Fire_flying = df[(df["Type1"] == "Fire") &
                 (df["Type2"] == "Flying")]
# print(Fire_flying)
# Out:
#             Type1     Type2  Height
# Name
# Poliwag     Water       NaN     0.6
# Poliwrath   Water  Fighting     1.3
# Tentacruel  Water    Poison     1.6
